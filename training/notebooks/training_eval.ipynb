# %% [markdown]
# # UrbanSim WM - Training and Evaluation Notebook
#
# This notebook provides tools for:
# - Training the world model
# - Evaluating model predictions
# - Visualizing latent representations
# - Policy simulation experiments
